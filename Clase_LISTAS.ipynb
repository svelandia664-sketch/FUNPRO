# %% [markdown]
# <a href="https://colab.research.google.com/github/svelandia664-sketch/FUNPRO/blob/main/Clase_LISTAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LISTAS
# Son tipos de datos que cumplen con tres caracteristicas
# 1. Finita: Se puede contar cuantos elementos tiene la lista.
# 2. Homogenea: Solo almacena un dato en especifico
# 3. Ordenada o index: sabemos que dato ocupa cada posicion
#
# Sintaxis
# ```
# # Lista vacía
# lista=[]
# # Manual:
# flores=["rosa","azucena","amapola","jazmín"]
# ```

# %%
n=10
s=0
m=0
for e in range(n):
    sueldo=int(input(f"Ingrese el sueldo del trabajador {e+1}: "))
    s=sueldo+s #acumulador
prom=s/n
print(f"El sueldo promedio de la empresa es: {prom}")
for e in range(n):
    sueldo=int(input(f"Ingrese el sueldo del trabajador {e+1}: "))
    if sueldo>prom: m=m+1
print(f"{m} trabajadores ganan mas que el promedio")
#Problema: Ejercicio sin memoria
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1307674912.py in <cell line: 0>()
#       3 m=0
#       4 for e in range(n):
# ----> 5     sueldo=int(input(f"Ingrese el sueldo del trabajador {e+1}: "))
#       6     s=sueldo+s #acumulador
#       7 prom=s/n
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
n=10
s=0
m=0
sueldo=[]
for e in range(n):
    sueldo.append(int(input(f"Ingrese el sueldo del trabajador {e+1}: ")))
    s=sueldo[e]+s #acumulador
prom=s/n
print(f"El sueldo promedio de la empresa es: {prom}")
for e in range(n):
    if sueldo[e]>prom: m=m+1
print(f"{m} trabajadores ganan mas que el promedio")
# Out:
# Ingrese el sueldo del trabajador 1: 1000
# Ingrese el sueldo del trabajador 2: 200
# Ingrese el sueldo del trabajador 3: 500
# Ingrese el sueldo del trabajador 4: 400
# Ingrese el sueldo del trabajador 5: 8200
# Ingrese el sueldo del trabajador 6: 400
# Ingrese el sueldo del trabajador 7: 600
# Ingrese el sueldo del trabajador 8: 200
# Ingrese el sueldo del trabajador 9: 7000
# Ingrese el sueldo del trabajador 10: 80000
# El sueldo promedio de la empresa es: 9850.0
# 1 trabajadores ganan mas que el promedio

# %%
n=[]
for notas in range(1,6):
  n.append(float(input(f"Ingrese la nota {notas}: ")))
# Out:
# Ingrese la nota 1: 2
# Ingrese la nota 2: 4
# Ingrese la nota 3: 4
# Ingrese la nota 4: 0
# Ingrese la nota 5: 5

# %%
m1=n.copy()

# %%
if n[0]<n[1]<n[2]<n[3]<n[4]:
  print(f"Se va a eliminar la nota {n[0]}")
  n.remove(n[0])
elif n[1]<n[2]<n[3]<n[4]:
  print(f"Se va a eliminar la nota {n[1]}")
  n.remove(n[1])
elif n[2]<n[3]<n[4]:
  print(f"Se va a eliminar la nota {n[2]}")
  n.remove(n[2])
elif n[3]<n[4]:
  print(f"Se va a eliminar la nota {n[3]}")
  n.remove(n[3])
else:
  print(f"Se va a eliminar la nota {n[4]}")
  n.remove(n[4])
# Out:
# Se va a eliminar la nota 0.0

# %%
#forma 2
min=5.0
for notas in range(4):
    if n[notas]<min:
      min=n[notas]
      print(f"La nueva nota menor es: {min}")
# Out:
# La nueva nota menor es: 2.0

# %%
#forma 3
min(n)
# Out:
# 1.0

# %%
#Quiero crear un programa que me imprima letra por letra
"""
Comportamiento de un para cuando usa con listas
for letra in lista:
  1. El para se repite la cantidad de veces de elementos que tiene la lista
  2. La variable adopta el valor de cada elemento de la lista
"""
c=1
for letra in a:
  print(f{c}.{letra})
  c=c+1
# Out:
#   File "/tmp/ipython-input-2245009513.py", line 10
#     print(f{c}.{letra})
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
for letra in range(len(a)):
  print(f"{letra+1}. {a[letra]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2856253687.py in <cell line: 0>()
# ----> 1 for letra in range(len(a)):
#       2   print(f"{letra+1}. {a[letra]}")
#
# NameError: name 'a' is not defined

# %%
for letra in a:
  print(f"a.index(letra)")

# %%
#Lograr que si entre gaki, salga hola
nombre="Gaki"
resultado=""
for letra in range(len(nombre)):
  if nombre[letra]=="G": resultado=resultado+"h"
  elif nombre[letra]=="a": resultado=resultado+"o"
  elif nombre[letra]=="k": resultado=resultado+"l"
  elif nombre[letra]=="i": resultado=resultado+"a"
  else: resultado=resultado+a[letra]
print(resultado)
# Out:
# hola

# %%
#Cualquier mensaje codificado, se traduzca
nombre="orza or emi ñqeozi"
resultado=""
for letra in range(len(nombre)):
  if nombre[letra]=="o": resultado=resultado+"e"
  elif nombre[letra]=="r": resultado=resultado+"o"
  elif nombre[letra]=="z": resultado=resultado+"l"
  elif nombre[letra]=="a": resultado=resultado+"o"
  elif nombre[letra]=="o": resultado=resultado+"o"
  elif nombre[letra]=="r": resultado=resultado+"l"
  elif nombre[letra]=="e": resultado=resultado+"u"
  elif nombre[letra]=="m": resultado=resultado+"a"
  elif nombre[letra]=="i": resultado=resultado+"a"
  elif nombre[letra]=="ñ": resultado=resultado+"o"
  elif nombre[letra]=="q": resultado=resultado+"l"
  elif nombre[letra]=="e": resultado=resultado+"a"
  elif nombre[letra]=="o": resultado=resultado+"a"
  elif nombre[letra]=="z": resultado=resultado+"a"
  elif nombre[letra]=="i": resultado=resultado+"a"


  else: resultado=resultado+a[letra]
print(resultado)
