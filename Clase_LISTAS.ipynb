# %% [markdown]
# <a href="https://colab.research.google.com/github/svelandia664-sketch/FUNPRO/blob/main/Clase_LISTAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LISTAS
# Son tipos de datos que cumplen con tres caracteristicas
# 1. Finita: Se puede contar cuantos elementos tiene la lista.
# 2. Homogenea: Solo almacena un dato en especifico
# 3. Ordenada o index: sabemos que dato ocupa cada posicion
#
# Sintaxis
# ```
# # Lista vacía
# lista=[]
# # Manual:
# flores=["rosa","azucena","amapola","jazmín"]
# ```

# %%
n=10
s=0
m=0
for e in range(n):
    sueldo=int(input(f"Ingrese el sueldo del trabajador {e+1}: "))
    s=sueldo+s #acumulador
prom=s/n
print(f"El sueldo promedio de la empresa es: {prom}")
for e in range(n):
    sueldo=int(input(f"Ingrese el sueldo del trabajador {e+1}: "))
    if sueldo>prom: m=m+1
print(f"{m} trabajadores ganan mas que el promedio")
#Problema: Ejercicio sin memoria
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1307674912.py in <cell line: 0>()
#       3 m=0
#       4 for e in range(n):
# ----> 5     sueldo=int(input(f"Ingrese el sueldo del trabajador {e+1}: "))
#       6     s=sueldo+s #acumulador
#       7 prom=s/n
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
n=10
s=0
m=0
sueldo=[]
for e in range(n):
    sueldo.append(int(input(f"Ingrese el sueldo del trabajador {e+1}: ")))
    s=sueldo[e]+s #acumulador
prom=s/n
print(f"El sueldo promedio de la empresa es: {prom}")
for e in range(n):
    if sueldo[e]>prom: m=m+1
print(f"{m} trabajadores ganan mas que el promedio")
# Out:
# Ingrese el sueldo del trabajador 1: 1000
# Ingrese el sueldo del trabajador 2: 200
# Ingrese el sueldo del trabajador 3: 500
# Ingrese el sueldo del trabajador 4: 400
# Ingrese el sueldo del trabajador 5: 8200
# Ingrese el sueldo del trabajador 6: 400
# Ingrese el sueldo del trabajador 7: 600
# Ingrese el sueldo del trabajador 8: 200
# Ingrese el sueldo del trabajador 9: 7000
# Ingrese el sueldo del trabajador 10: 80000
# El sueldo promedio de la empresa es: 9850.0
# 1 trabajadores ganan mas que el promedio

# %%
n=[]
for notas in range(1,6):
  n.append(float(input(f"Ingrese la nota {notas}: ")))
# Out:
# Ingrese la nota 1: 2
# Ingrese la nota 2: 4
# Ingrese la nota 3: 4
# Ingrese la nota 4: 0
# Ingrese la nota 5: 5

# %%
m1=n.copy()

# %%
if n[0]<n[1]<n[2]<n[3]<n[4]:
  print(f"Se va a eliminar la nota {n[0]}")
  n.remove(n[0])
elif n[1]<n[2]<n[3]<n[4]:
  print(f"Se va a eliminar la nota {n[1]}")
  n.remove(n[1])
elif n[2]<n[3]<n[4]:
  print(f"Se va a eliminar la nota {n[2]}")
  n.remove(n[2])
elif n[3]<n[4]:
  print(f"Se va a eliminar la nota {n[3]}")
  n.remove(n[3])
else:
  print(f"Se va a eliminar la nota {n[4]}")
  n.remove(n[4])
# Out:
# Se va a eliminar la nota 0.0

# %%
#forma 2
min=5.0
for notas in range(4):
    if n[notas]<min:
      min=n[notas]
      print(f"La nueva nota menor es: {min}")
# Out:
# La nueva nota menor es: 2.0

# %%
#forma 3
min(n)
# Out:
# 1.0
