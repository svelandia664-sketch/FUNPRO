# %% [markdown]
# <a href="https://colab.research.google.com/github/svelandia664-sketch/FUNPRO/blob/main/Clase_8_Estructuras_de_seleccion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##ESTRUCTURA PARA/for
# * La estructura para se emplea cuando se sabe **cuantas veces** se repite una accion

# %%
#Hacer un programa que calcule la nomina de n empleado
nomina=0
n=int(input("Ingrese la cantidad de empleados: "))
for s in range(n,):
  sueldo=int(input(f"Ingrese el salario del empleado {s+1}: "))
  nomina=nomina+sueldo #Acumulador
print(f"La nomina de {n} empleados es: {nomina}")
# Out:
# Ingrese la cantidad de empleados: 3
# Ingrese el salario del empleado 1: 10
# Ingrese el salario del empleado 2: 20
# Ingrese el salario del empleado 3: 5
# La nomina de 3 empleados es: 35
