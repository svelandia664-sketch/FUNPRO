# %% [markdown]
# <a href="https://colab.research.google.com/github/svelandia664-sketch/FUNPRO/blob/main/Ejercicios_clase_if_elif_else_match.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=float(input("Ingrese un numero: "))

if num>0:
    print("Es un numero positivo")
elif num<0:
      print("Es un numero negativo")
else:
        print("Es cero")
# Out:
# Ingrese un numero: 0.1
# Es un numero positivo

# %%
año=int(input("Ingrese el año: "))

if año % 4==0:
    if año % 100==0:
        if año % 400==0:
            print("Bisiesto")
        else:
            print("No Bisiesto")
    else:
        print("Bisiesto")
else:
    print("No Bisiesto")
# Out:
# Ingrese el año: 2036
# Bisiesto

# %%
peso=float(input("Ingrese su peso: "))
alt=float(input("Ingrese su altura: "))
imc=peso / (alt ** 2)

if imc < 18.5:
    print("Bajo peso")
elif 18.5 <= imc < 24.9:
    print("Peso normal")
elif 25.0 <= imc < 29.9:
    print("Sobrepeso")
else:
    print("Obesidad")
# Out:
# Ingrese su peso: 180
# Ingrese su altura: 1.80
# Obesidad

# %%
print("1. Suma")
print("2. Resta")
print("3. Multiplicación")
print("4. División")

opcion = int(input("Elija una opción: "))
n1 = float(input("Ingrese el primer número: "))
n2 = float(input("Ingrese el segundo número: "))

match opcion:
    case 1:
        print("Resultado:", n1 + n2)
    case 2:
        print("Resultado:", n1 - n2)
    case 3:
        print("Resultado:", n1 * n2)
    case 4:
        if n2 == 0:
            print("No se puede dividir entre cero")
        else:
            print("Resultado:", n1 / n2)
    case _:
        print("Opción no válida")
# Out:
# 1. Suma
# 2. Resta
# 3. Multiplicación
# 4. División
# Elija una opción: 1
# Ingrese el primer número: 2
# Ingrese el segundo número: 3
# Resultado: 5.0

# %%
lado1 = float(input("Ingrese el primer lado: "))
lado2 = float(input("Ingrese el segundo lado: "))
lado3 = float(input("Ingrese el tercer lado: "))

if lado1 == lado2 and lado2 == lado3:
    print("Equilátero")
elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
    print("Isósceles")
else:
    print("Escaleno")

# %% [markdown]
# ![photo_5082638803620531025_y.jpg](data:image/jpeg;base64,...)![photo_5082638803620531024_y.jpg](data:image/jpeg;base64,...)
