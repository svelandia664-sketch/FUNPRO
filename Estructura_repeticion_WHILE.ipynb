# %% [markdown]
# <a href="https://colab.research.google.com/github/svelandia664-sketch/FUNPRO/blob/main/Estructura_repeticion_WHILE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![WhatsApp Image 2025-10-22 at 8.44.31 AM.jpeg](data:image/jpeg;base64,...)![WhatsApp Image 2025-10-22 at 8.44.40 AM.jpeg](data:image/jpeg;base64,...)

# %%
num = int(input("Digite el numero: "))
cubo= num * num * num

while num > 0:
    cubo = num * num * num
    print("El cubo de", num, "es", cubo)
    num = int(input("Digite otro número: "))

print("Fin de la programacion.")
# Out:
# Digite el numero: 2
# El cubo de 2 es 8
# Digite otro número: -1
# Fin de la programacion.

# %%
contrasena = input("Introduce la contraseña: ")
letras = int(input("¿Cuántas letras tiene su contraseña? "))

while letras < 6:
    print("Contraseña débil, intente otra.")
    contrasena = input("Ingrese una nueva contraseña: ")
    letras = int(input("¿Cuántas letras tiene su nueva contraseña? "))

print("Aceptada.")
# Out:
# Introduce la contraseña: casa
# ¿Cuántas letras tiene su contraseña? 4
# Contraseña débil, intente otra.
# Ingrese una nueva contraseña: casamiento
# ¿Cuántas letras tiene su nueva contraseña? 9
# Aceptada.
